# %%
import pandas as pd

# %%
df = pd.read_csv("cumulative_2025.09.30_00.52.21.csv", comment='#')

# %%
df.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  ...  \
# 0      1.000              0              0              0              0  ...
# 1      0.969              0              0              0              0  ...
# 2      0.000              0              0              0              0  ...
# 3      0.000              0              1              0              0  ...
# 4      1.000              0              0              0              0  ...
#
# ...

# %%
df["koi_disposition"].unique()
# Out:
# array(['CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
df["koi_pdisposition"].unique()
# Out:
# array(['CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
df.columns
# Out:
# Index(['kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_time0bk',
#        'koi_impact', 'koi_duration', 'koi_depth', 'koi_prad', 'koi_teq',
#        'koi_insol', 'koi_model_snr', 'koi_tce_plnt_num', 'koi_tce_delivname',
#        'koi_steff', 'koi_slogg', 'koi_srad', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
df.describe()
# Out:
#               kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# count  9.564000e+03  8054.000000    9564.000000    9564.000000    9564.000000
# mean   7.690628e+06     0.480829       0.208595       0.232748       0.197512
# std    2.653459e+06     0.476928       4.767290       0.422605       0.398142
# min    7.574500e+05     0.000000       0.000000       0.000000       0.000000
# 25%    5.556034e+06     0.000000       0.000000       0.000000       0.000000
# 50%    7.906892e+06     0.334000       0.000000       0.000000       0.000000
# 75%    9.873066e+06     0.998000       0.000000       0.000000       0.000000
# max    1.293514e+07     1.000000     465.000000       1.000000       1.000000
#
#        koi_fpflag_ec     koi_period  koi_time0bk   koi_impact  koi_duration  \
# count    9564.000000    9564.000000  9564.000000  9201.000000   9564.000000
# mean        0.120033      75.671358   166.183251     0.735105      5.621606
# ...

# %%
df.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  ...  \
# 0      1.000              0              0              0              0  ...
# 1      0.969              0              0              0              0  ...
# 2      0.000              0              0              0              0  ...
# 3      0.000              0              1              0              0  ...
# 4      1.000              0              0              0              0  ...
#
# ...

# %%
df["koi_tce_delivname"].value_counts(), df["koi_tce_delivname"].unique()
# Out:
# (koi_tce_delivname
#  q1_q17_dr25_tce    8054
#  q1_q16_tce          796
#  q1_q17_dr24_tce     368
#  Name: count, dtype: int64,
#  array(['q1_q17_dr25_tce', 'q1_q16_tce', nan, 'q1_q17_dr24_tce'],
#        dtype=object))

# %%
df.isnull().sum()*100/len(df)
# Out:
# kepid                 0.000000
# kepoi_name            0.000000
# kepler_name          71.277708
# koi_disposition       0.000000
# koi_pdisposition      0.000000
# koi_score            15.788373
# koi_fpflag_nt         0.000000
# koi_fpflag_ss         0.000000
# koi_fpflag_co         0.000000
# koi_fpflag_ec         0.000000
# koi_period            0.000000
# koi_time0bk           0.000000
# koi_impact            3.795483
# koi_duration          0.000000
# koi_depth             3.795483
# koi_prad              3.795483
# koi_teq               3.795483
# koi_insol             3.356336
# koi_model_snr         3.795483
# koi_tce_plnt_num      3.617733
# koi_tce_delivname     3.617733
# koi_steff             3.795483
# koi_slogg             3.795483
# koi_srad              3.795483
# ra                    0.000000
# dec                   0.000000
# koi_kepmag            0.010456
# dtype: float64

# %%
df["kepler_name"].isnull().sum()*100/len(df)
# Out:
# np.float64(71.27770807193643)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(12245)

# %%
df["koi_score"].isnull().sum()
# Out:
# np.int64(1510)
